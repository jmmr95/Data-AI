# %% [markdown]
# # HR Analytics Dashboard

# %% [markdown]
# # [Enlace Público al Dashboard](https://public.tableau.com/views/HRAnalyticsDashboard_17524198468530/HRAnalysticsDashboard?:language=es-ES&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
