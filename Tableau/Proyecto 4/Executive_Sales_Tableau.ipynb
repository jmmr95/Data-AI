# %% [markdown]
# # Executive Sales

# %% [markdown]
# # [Enlace Público al Dashboard](https://public.tableau.com/views/ExecutiveSales_16684440929750/ExecDashboard?:language=es-ES&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
