# %% [markdown]
# # Eccomerce Sales

# %% [markdown]
# # [Enlace Público al Dashboard](https://public.tableau.com/views/EccomerceSales_17524199394360/ECCOMERCESALESDASHBOARD?:language=es-ES&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
