# %% [markdown]
# # Walmart Retail Data Analysis

# %% [markdown]
# # [Enlace Público al Dashboard](https://public.tableau.com/views/WalmartRetailDataAnalysis_16684558268000/WalmartRetailDataAnalysis?:language=es-ES&:sid=&:redirect=auth&:display_count=n&:origin=viz_share_link)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
